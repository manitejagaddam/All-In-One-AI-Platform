# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Data/heart disease.csv")

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.shape
# Out:
# (918, 12)

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.sample(2)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 15    54   F           ATA        120          273          0     Normal
# 373   59   M           ASY        135            0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 15     150              N      1.5     Flat             0
# 373    115              Y      1.0     Flat             1

# %%
df["ChestPainType"].unique()
# Out:
# array(['ATA', 'NAP', 'ASY', 'TA'], dtype=object)

# %%
df['RestingECG'].unique()
# Out:
# array(['Normal', 'ST', 'LVH'], dtype=object)

# %%
df = pd.get_dummies(df, columns=["Sex", "ChestPainType", "RestingECG", "ExerciseAngina", "ST_Slope"], dtype = int, drop_first = True)

# %%
df.head()
# Out:
#    Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0   40        140          289          0    172      0.0             0
# 1   49        160          180          0    156      1.0             1
# 2   37        130          283          0     98      0.0             0
# 3   48        138          214          0    108      1.5             1
# 4   54        150          195          0    122      0.0             0
#
#    Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0      1                  1                  0                 0
# 1      0                  0                  1                 0
# 2      1                  1                  0                 0
# 3      0                  0                  0                 0
# 4      1                  0                  1                 0
#
#    RestingECG_Normal  RestingECG_ST  ExerciseAngina_Y  ST_Slope_Flat  \
# ...

# %%
X = df.drop("HeartDisease", axis = 1)
y = df['HeartDisease']

# %%
X
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_M  \
# 0     40        140          289          0    172      0.0      1
# 1     49        160          180          0    156      1.0      0
# 2     37        130          283          0     98      0.0      1
# 3     48        138          214          0    108      1.5      0
# 4     54        150          195          0    122      0.0      1
# ..   ...        ...          ...        ...    ...      ...    ...
# 913   45        110          264          0    132      1.2      1
# 914   68        144          193          1    141      3.4      1
# 915   57        130          131          0    115      1.2      1
# 916   57        130          236          0    174      0.0      0
# 917   38        138          175          0    173      0.0      1
#
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0                    1                  0                 0
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 456)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lg = LogisticRegression()

# %%
lg.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred_lg = lg.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_pred_lg)
# Out:
# 0.8858695652173914

# %%
import pickle as pkl

# %%
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline([
    ("Scaling", StandardScaler()), 
    ("LogisticRegression", LogisticRegression())
])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('Scaling', StandardScaler()),
#                 ('LogisticRegression', LogisticRegression())])

# %%
y_pred_pipe = pipe.predict(X_test)

# %%
accuracy_score(y_test, y_pred_pipe)
# Out:
# 0.8858695652173914

# %%
X_test
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_M  \
# 776   62        150          244          0    154      1.4      0
# 863   60        140          185          0    155      3.0      1
# 397   58        170            0          1    105      0.0      1
# 551   62        120          220          0     86      0.0      1
# 664   65        150          225          0    114      1.0      0
# ..   ...        ...          ...        ...    ...      ...    ...
# 605   51        114          258          1     96      1.0      0
# 297   57        110            0          1    131      1.4      1
# 858   62        140          268          0    160      3.6      0
# 242   55        160          292          1    143      2.0      1
# 114   49        130          207          0    135      0.0      0
#
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 776                  0                  0                 0
# ...

# %%
X_test.columns
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'Sex_M', 'ChestPainType_ATA', 'ChestPainType_NAP', 'ChestPainType_TA',
#        'RestingECG_Normal', 'RestingECG_ST', 'ExerciseAngina_Y',
#        'ST_Slope_Flat', 'ST_Slope_Up'],
#       dtype='object')

# %%
import pickle as pkl

# %%
pkl.dump(pipe, open("Models/hearDisease.pkl", "wb"))
